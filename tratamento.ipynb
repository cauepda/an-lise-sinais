# %%
import pandas as pd

# %%
df = pd.read_csv('mensagens.csv')
df.loc[:, "data"] = pd.to_datetime(df["data"])
df
# Out:
# /var/folders/7r/53d07l7929sfvc38qj5yzz680000gn/T/ipykernel_30767/1464333423.py:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "data"] = pd.to_datetime(df["data"])
#         id                data       autor_id  \
# 0     6571 2025-09-08 21:34:25 -1002836003329
# 1     6570 2025-09-08 21:32:26 -1002836003329
# 2     6569 2025-09-08 21:30:31 -1002836003329
# 3     6568 2025-09-08 21:30:29 -1002836003329
# 4     6567 2025-09-08 21:30:28 -1002836003329
# ...    ...                 ...            ...
# 6487    71 2025-08-14 00:22:26 -1002836003329
# 6488    70 2025-08-14 00:20:30 -1002836003329
# 6489    69 2025-08-14 00:19:43 -1002836003329
# 6490    65 2025-08-14 00:15:51 -1002836003329
# 6491     1 2025-08-13 21:38:56 -1002836003329
#
# ...

# %%
df.loc[:, "data"] = df["data"] - pd.Timedelta(hours=3)
df
# Out:
# /var/folders/7r/53d07l7929sfvc38qj5yzz680000gn/T/ipykernel_30767/701828918.py:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "data"] = df["data"] - pd.Timedelta(hours=3)
#         id                data       autor_id  \
# 0     6571 2025-09-08 18:34:25 -1002836003329
# 1     6570 2025-09-08 18:32:26 -1002836003329
# 2     6569 2025-09-08 18:30:31 -1002836003329
# 3     6568 2025-09-08 18:30:29 -1002836003329
# 4     6567 2025-09-08 18:30:28 -1002836003329
# ...    ...                 ...            ...
# 6487    71 2025-08-13 21:22:26 -1002836003329
# 6488    70 2025-08-13 21:20:30 -1002836003329
# 6489    69 2025-08-13 21:19:43 -1002836003329
# 6490    65 2025-08-13 21:15:51 -1002836003329
# 6491     1 2025-08-13 18:38:56 -1002836003329
#
# ...

# %%
list_keep_values = [
    'STOP em ETH/USDT',
    'STOP em BTC/USDT',
    'WIN em ETH/USDT',
    'WIN em BTC/USDT',
    'WIN (G1) em BTC/USDT',  # Fixed: removed the ✅ ** ** ✅ formatting
    'WIN (G1) em ETH/USDT',
    'WIN (G2) em BTC/USDT',
    'WIN (G2) em ETH/USDT',
    'Novo Sinal Encontrado',
    'Faça o GALE 2 para ETH/USDT',
    'Faça o GALE 2 para BTC/USDT',
    'Faça o GALE 1 para BTC/USDT',
    'Faça o GALE 1 para ETH/USDT',
]

# This list will be used with proper regex escaping in the next cell

# %%
import re

# Create a proper list of values to keep (without special regex characters)
keep_values_clean = [
    'STOP em ETH/USDT',
    'STOP em BTC/USDT', 
    'WIN em ETH/USDT',
    'WIN em BTC/USDT',
    'WIN (G1) em BTC/USDT',
    'WIN (G1) em ETH/USDT',
    'WIN (G2) em BTC/USDT', 
    'WIN (G2) em ETH/USDT',
    'Novo Sinal Encontrado',
    'Faça o GALE 2 para ETH/USDT',
    'Faça o GALE 2 para BTC/USDT', 
    'Faça o GALE 1 para BTC/USDT',
    'Faça o GALE 1 para ETH/USDT',
]

# Create regex pattern by escaping special characters
pattern = '|'.join([re.escape(value) for value in keep_values_clean])

# Apply the filter
df = df[df['mensagem'].str.contains(pattern, na=False, regex=True)]

# Remove unwanted messages (if needed)
df = df[~df['mensagem'].str.contains('AVISO IMPORTANTE', na=False)]

for mensagem in df.mensagem.unique():
    if "G1" in mensagem or "G2" in mensagem:
# Out:
# ✅ **WIN (G1) em BTC/USDT** ✅
# ✅ **WIN (G2) em BTC/USDT** ✅
# ✅ **WIN (G1) em ETH/USDT** ✅
# ✅ **WIN (G2) em ETH/USDT** ✅
# ✅ WIN (G2) em ETH/USDT ✅

# %%
df.to_csv('mensagens_tratadas.csv', index=False)
